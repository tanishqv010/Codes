# %%
import matplotlib.pyplot as plt

def draw_line(x1, y1, x2, y2):
    dx=x2-x1
    dy=y2-y1
    step=max(abs(dx),abs(dy))
    xinc=dx/step
    yinc=dy/step
    X=[x1]
    Y=[y1]
    i=0
    while(i<step):
      x1=x1+xinc
      y1=y1+yinc
      X.append(x1)
      Y.append(y1)
      i+=1    
    plt.plot(X,Y)
    
x1=float(input("Enter x1:"))
y1=float(input("Enter y1:"))

x2=float(input("Enter x2:"))
y2=float(input("Enter y2:"))

x3=float(input("Enter x3:"))
y3=float(input("Enter y3:"))

draw_line(x1, y1, x2, y2)
draw_line(x2, y2, x3, y3)
draw_line(x1, y1, x3, y3)

plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.grid(True)
plt.title("Triangle using DDA algorithm")
plt.plot()
# Out:
# Enter x1: 10
# Enter y1: 13
# Enter x2: 12
# Enter y2: 11
# Enter x3: 2
# Enter y3: 16
# []
