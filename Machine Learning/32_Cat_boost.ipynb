# %% [markdown]
# Importing the Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Importing the Dataset

# %%
dataset = pd.read_csv(r'C:\Users\hp\Downloads\Courses\ML\GetFreeCourses.Co-Udemy-Machine Learning A-Z™ Python & R in Data Science [2023]\47. CatBoost\Data.csv')
X = dataset.iloc[:, : -1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# Splitting the Dataset into the Training Set and the Test Set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# Training the Catboost Model on the Training Set

# %%
from catboost import CatBoostClassifier
classifier = CatBoostClassifier()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
# Out:
# Learning rate set to 0.007956
# 0:	learn: 0.6778283	total: 144ms	remaining: 2m 23s
# 1:	learn: 0.6642874	total: 147ms	remaining: 1m 13s
# 2:	learn: 0.6510578	total: 151ms	remaining: 50.1s
# 3:	learn: 0.6351685	total: 155ms	remaining: 38.6s
# 4:	learn: 0.6203906	total: 158ms	remaining: 31.5s
# 5:	learn: 0.6053561	total: 162ms	remaining: 26.8s
# 6:	learn: 0.5913363	total: 165ms	remaining: 23.4s
# 7:	learn: 0.5773888	total: 169ms	remaining: 21s
# 8:	learn: 0.5638394	total: 173ms	remaining: 19s
# 9:	learn: 0.5507421	total: 176ms	remaining: 17.5s
# 10:	learn: 0.5377201	total: 180ms	remaining: 16.2s
# 11:	learn: 0.5243873	total: 184ms	remaining: 15.1s
# 12:	learn: 0.5129034	total: 187ms	remaining: 14.2s
# 13:	learn: 0.5047204	total: 190ms	remaining: 13.4s
# 14:	learn: 0.4942404	total: 197ms	remaining: 13s
# 15:	learn: 0.4836253	total: 201ms	remaining: 12.4s
# 16:	learn: 0.4733355	total: 204ms	remaining: 11.8s
# 17:	learn: 0.4629416	total: 208ms	remaining: 11.4s
# ...

# %% [markdown]
# Making Confusion Matrix and Finding the Accuracy Score

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
score = accuracy_score(y_test, y_pred)
print(score)
# Out:
# [[84  3]
#  [ 0 50]]
# 0.9781021897810219

# %% [markdown]
# Applying k-Fold Cross Validation

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
print('Accuracy : {:.2f} %'.format(accuracies.mean() * 100))
print('Standard Deviation : {:.2f} %'.format(accuracies.std() * 100))
# Out:
# Learning rate set to 0.007604
# 0:	learn: 0.6772057	total: 3.58ms	remaining: 3.58s
# 1:	learn: 0.6652633	total: 6.91ms	remaining: 3.45s
# 2:	learn: 0.6511784	total: 10.3ms	remaining: 3.44s
# 3:	learn: 0.6360094	total: 14ms	remaining: 3.48s
# 4:	learn: 0.6221218	total: 17.5ms	remaining: 3.48s
# 5:	learn: 0.6065689	total: 21ms	remaining: 3.49s
# 6:	learn: 0.5931935	total: 24.5ms	remaining: 3.48s
# 7:	learn: 0.5783827	total: 27.4ms	remaining: 3.39s
# 8:	learn: 0.5646398	total: 30.8ms	remaining: 3.39s
# 9:	learn: 0.5508871	total: 34.1ms	remaining: 3.38s
# 10:	learn: 0.5390346	total: 37.7ms	remaining: 3.39s
# 11:	learn: 0.5279564	total: 40.8ms	remaining: 3.36s
# 12:	learn: 0.5181720	total: 44.5ms	remaining: 3.38s
# 13:	learn: 0.5055409	total: 48.5ms	remaining: 3.41s
# 14:	learn: 0.4943123	total: 52.3ms	remaining: 3.43s
# 15:	learn: 0.4824866	total: 55.9ms	remaining: 3.44s
# 16:	learn: 0.4729889	total: 59.5ms	remaining: 3.44s
# 17:	learn: 0.4638986	total: 63.2ms	remaining: 3.45s
# ...
